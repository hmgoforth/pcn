# %%
# %matplotlib nbagg
import argparse
import importlib
import models
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from open3d import *

# %%
def plot_pcd(ax, pcd):
    ax.scatter(pcd[:, 0], pcd[:, 1], pcd[:, 2], zdir='y', c=pcd[:, 0], s=0.5, cmap='Reds', vmin=-1, vmax=0.5)
    ax.set_axis_off()
    ax.set_xlim(-0.3, 0.3)
    ax.set_ylim(-0.3, 0.3)
    ax.set_zlim(-0.3, 0.3)

# %%
pcd = read_point_cloud('/code/demo_data/car.pcd')
pcd_points = np.array(pcd.points)
pcd_downsample = pcd_points[::8]

# %%
fig, axes = plt.subplots()
axes= plt.axes(projection='3d')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.show()
plot_pcd(axes, pcd_points)

# %%
fig2, axes2 = plt.subplots()
axes2= plt.axes(projection='3d')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.show()
plot_pcd(axes2, pcd_downsample)

# %%
inputs = tf.placeholder(tf.float32, (1, None, 3))
gt = tf.placeholder(tf.float32, (1, 1638, 3))
model_module = importlib.import_module('.%s' %'pcn_cd', 'models')
model = model_module.Model(inputs, gt, tf.constant(1.0))

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.allow_soft_placement = True
sess = tf.Session(config=config)

saver = tf.train.Saver()
saver.restore(sess, '/code/data/trained_models/pcn_cd')
# Out:
# INFO:tensorflow:Restoring parameters from /code/data/trained_models/pcn_cd

# %%
pcd
# Out:
# geometry::PointCloud with 1511 points.

# %%
complete = sess.run(model.outputs, feed_dict={inputs: [pcd_points]})[0]

# %%
complete.shape
# Out:
# (16384, 3)

# %%
complete_downsample = sess.run(model.outputs, feed_dict={inputs: [pcd_downsample]})[0]

# %%
fig3, axes3 = plt.subplots()
axes3= plt.axes(projection='3d')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.show()
plot_pcd(axes3, complete)

# %%
fig4, axes4 = plt.subplots()
axes4= plt.axes(projection='3d')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.show()
plot_pcd(axes4, complete_downsample)

# %%
# fig5, axes5 = plt.subplots()
# axes5= plt.axes(projection='3d')
# draw_geometries([pcd])

# %%
# import open3d as o3
# fragment = o3.read_point_cloud('/code/demo_data/fragment.ply')
# visualizer = JVisualizer()
# visualizer.add_geometry(fragment)
# visualizer.show()

# %%
# write_point_cloud('/code/demo_data/dense.ply', complete)

# %%
def generate_3d():
    """Generate a 3D random rotation matrix.
    Returns:
        np.matrix: A 3D rotation matrix.
    """
    x1, x2, x3 = np.random.rand(3)
    R = np.matrix([[np.cos(2 * np.pi * x1), np.sin(2 * np.pi * x1), 0],
                   [-np.sin(2 * np.pi * x1), np.cos(2 * np.pi * x1), 0],
                   [0, 0, 1]])
    v = np.matrix([[np.cos(2 * np.pi * x2) * np.sqrt(x3)],
                   [np.sin(2 * np.pi * x2) * np.sqrt(x3)],
                   [np.sqrt(1 - x3)]])
    H = np.eye(3) - 2 * v * v.T
    M = -H * R
    return M

# %%
M = generate_3d()

# %%
pcd_points.shape
# Out:
# (1511, 3)

# %%
import cv2
pcd_points_rotated= cv2.transform(np.reshape(pcd_points, (1511,1,3)), M)

# %%
fig5, axes5 = plt.subplots()
axes5 = plt.axes(projection='3d')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.show()
plot_pcd(axes5,pcd_points_rotated.reshape(1511,3))

# %%
complete_rotated = sess.run(model.outputs, feed_dict={inputs: [pcd_points_rotated.reshape(1511,3)]})[0]

# %%
fig5, axes6 = plt.subplots()
axes6 = plt.axes(projection='3d')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.show()
plot_pcd(axes6,complete_rotated)

# %%
def generate_2d():
    """Generate a 2D random rotation matrix.
    Returns:
        np.matrix: A 2D rotation matrix.
    """
    x = np.random.random()
    M = np.matrix([[np.cos(2 * np.pi * x), -np.sin(2 * np.pi * x)],
                   [np.sin(2 * np.pi * x), np.cos(2 * np.pi * x)]])
    return M

# %%
M_2 = generate_2d()

# %%
M.shape
# Out:
# (3, 3)

# %%
M3_z = np.eye(3)

# %%
M3_z[0, 0] = M_2[0,0]
M3_z[0, 2] = M_2[0,1]
M3_z[2, 0] = M_2[1,0]
M3_z[2, 2] = M_2[1,1]

# %%
M3_z
# Out:
# array([[-0.12088385,  0.        , -0.99266666],
#        [ 0.        ,  1.        ,  0.        ],
#        [ 0.99266666,  0.        , -0.12088385]])

# %%
pcd_points_rotated_Z= cv2.transform(np.reshape(pcd_points, (1511,1,3)), M3_z)

# %%
fig7, axes7 = plt.subplots()
axes7 = plt.axes(projection='3d')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.show()
plot_pcd(axes7,pcd_points_rotated_Z.reshape(1511,3))

# %%
complete_rotated_Z = sess.run(model.outputs, feed_dict={inputs: [pcd_points_rotated_Z.reshape(1511,3)]})[0]

# %%
fig8, axes8 = plt.subplots()
axes8 = plt.axes(projection='3d')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.show()
plot_pcd(axes8,complete_rotated_Z)
